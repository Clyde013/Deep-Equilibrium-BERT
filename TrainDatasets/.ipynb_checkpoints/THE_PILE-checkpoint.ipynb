# %% [markdown]
# https://pile.eleuther.ai/
#
# Remember to `!pip install zstandard`

# %%
from datasets import load_dataset

base_url = "https://mystic.the-eye.eu/public/AI/pile/"
data_files = {
    "train": [base_url + "train/" + f"{idx:02d}.jsonl.zst" for idx in range(30)],
    "validation": base_url + "val.jsonl.zst",
    "test": base_url + "test.jsonl.zst",
}
pile_dataset = load_dataset("json", data_files=data_files, streaming=True)
# Out:
# Resolving data files:   0%|          | 0/30 [00:00<?, ?it/s]
# Using custom data configuration default-ad49e2168ced215d

# %%
next(iter(pile_dataset["train"]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 next(iter(pile_dataset["train"]))
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\iterable_dataset.py:497, in IterableDataset.__iter__(self)
#     496 def __iter__(self):
# --> 497     for key, example in self._iter():
#     498         if self.features:
#     499             # we encode the example for ClassLabel feature types for example
#     500             encoded_example = self.features.encode_example(example)
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\iterable_dataset.py:494, in IterableDataset._iter(self)
#     492 else:
#     493     ex_iterable = self._ex_iterable
# --> 494 yield from ex_iterable
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\iterable_dataset.py:87, in ExamplesIterable.__iter__(self)
#      86 def __iter__(self):
# ---> 87     yield from self.generate_examples_fn(**self.kwargs)
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\iterable_dataset.py:439, in _generate_examples_from_tables_wrapper.<locals>.wrapper(**kwargs)
#     437 def wrapper(**kwargs):
#     438     python_formatter = PythonFormatter()
# --> 439     for key, table in generate_tables_fn(**kwargs):
#     440         batch = python_formatter.format_batch(table)
#     441         for i, example in enumerate(_batch_to_examples(batch)):
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\packaged_modules\json\json.py:85, in Json._generate_tables(self, files)
#      84 def _generate_tables(self, files):
# ---> 85     for file_idx, file in enumerate(files):
#      86
#      87         # If the file is one json object and if we need to look at the list of items in one specific field
#      88         if self.config.field is not None:
#      89             with open(file, encoding="utf-8") as f:
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\utils\streaming_download_manager.py:679, in _IterableFromGenerator.__iter__(self)
#     678 def __iter__(self):
# --> 679     yield from self.generator(*self.args, **self.kwargs)
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\utils\streaming_download_manager.py:728, in FilesIterable._iter_from_urlpaths(cls, urlpaths, use_auth_token)
#     726     urlpaths = [urlpaths]
#     727 for urlpath in urlpaths:
# --> 728     if xisfile(urlpath, use_auth_token=use_auth_token):
#     729         yield urlpath
#     730     else:
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\utils\streaming_download_manager.py:214, in xisfile(path, use_auth_token)
#     212 else:
#     213     storage_options = None
# --> 214 fs, *_ = fsspec.get_fs_token_paths(path, storage_options=storage_options)
#     215 return fs.isfile(main_hop)
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\fsspec\core.py:617, in get_fs_token_paths(urlpath, mode, num, name_function, storage_options, protocol, expand)
#     615     inkwargs["fo"] = urls
#     616 paths, protocol, _ = chain[0]
# --> 617 fs = filesystem(protocol, **inkwargs)
#     618 if isinstance(paths, (list, tuple, set)):
#     619     paths = [fs._strip_protocol(u) for u in paths]
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\fsspec\registry.py:253, in filesystem(protocol, **storage_options)
#     247 """Instantiate filesystems for given protocol and arguments
#     248
#     249 ``storage_options`` are specific to the protocol being chosen, and are
#     250 passed directly to the class.
#     251 """
#     252 cls = get_filesystem_class(protocol)
# --> 253 return cls(**storage_options)
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\fsspec\spec.py:68, in _Cached.__call__(cls, *args, **kwargs)
#      66     return cls._cache[token]
#      67 else:
# ---> 68     obj = super().__call__(*args, **kwargs)
#      69     # Setting _fs_token here causes some static linters to complain.
#      70     obj._fs_token_ = token
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\filesystems\compression.py:129, in ZstdFileSystem.__init__(self, fo, mode, target_protocol, target_options, block_size, **kwargs)
#     120 def __init__(
#     121     self,
#     122     fo: str,
#    (...)
#     127     **kwargs,
#     128 ):
# --> 129     super().__init__(
#     130         fo=fo,
#     131         mode=mode,
#     132         target_protocol=target_protocol,
#     133         target_options=target_options,
#     134         block_size=block_size,
#     135         **kwargs,
#     136     )
#     137     # We need to wrap the zstd decompressor to avoid this error in fsspec==2021.7.0 and zstandard==0.15.2:
#     138     #
#     139     # File "/Users/user/.virtualenvs/hf-datasets/lib/python3.7/site-packages/fsspec/core.py", line 145, in open
#    (...)
#     142     #
#     143     # see https://github.com/intake/filesystem_spec/issues/725
#     144     _enter = self.file.__enter__
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\datasets\filesystems\compression.py:37, in BaseCompressedFileFileSystem.__init__(self, fo, target_protocol, target_options, **kwargs)
#      35 super().__init__(self, **kwargs)
#      36 # always open as "rb" since fsspec can then use the TextIOWrapper to make it work for "r" mode
# ---> 37 self.file = fsspec.open(
#      38     fo, mode="rb", protocol=target_protocol, compression=self.compression, **(target_options or {})
#      39 )
#      40 self.compressed_name = os.path.basename(self.file.path.split("::")[0])
#      41 self.uncompressed_name = (
#      42     self.compressed_name[: self.compressed_name.rindex(".")]
#      43     if "." in self.compressed_name
#      44     else self.compressed_name
#      45 )
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\fsspec\core.py:462, in open(urlpath, mode, compression, encoding, errors, protocol, newline, **kwargs)
#     412 def open(
#     413     urlpath,
#     414     mode="rb",
#    (...)
#     420     **kwargs,
#     421 ):
#     422     """Given a path or paths, return one ``OpenFile`` object.
#     423
#     424     Parameters
#    (...)
#     460     ``OpenFile`` object.
#     461     """
# --> 462     return open_files(
#     463         urlpath=[urlpath],
#     464         mode=mode,
#     465         compression=compression,
#     466         encoding=encoding,
#     467         errors=errors,
#     468         protocol=protocol,
#     469         newline=newline,
#     470         expand=False,
#     471         **kwargs,
#     472     )[0]
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\fsspec\core.py:307, in open_files(urlpath, mode, compression, encoding, errors, name_function, num, protocol, newline, auto_mkdir, expand, **kwargs)
#     304     parents = {fs._parent(path) for path in paths}
#     305     [fs.makedirs(parent, exist_ok=True) for parent in parents]
#     306 return OpenFiles(
# --> 307     [
#     308         OpenFile(
#     309             fs,
#     310             path,
#     311             mode=mode,
#     312             compression=compression,
#     313             encoding=encoding,
#     314             errors=errors,
#     315             newline=newline,
#     316         )
#     317         for path in paths
#     318     ],
#     319     mode=mode,
#     320     fs=fs,
#     321 )
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\fsspec\core.py:308, in <listcomp>(.0)
#     304     parents = {fs._parent(path) for path in paths}
#     305     [fs.makedirs(parent, exist_ok=True) for parent in parents]
#     306 return OpenFiles(
#     307     [
# --> 308         OpenFile(
#     309             fs,
#     310             path,
#     311             mode=mode,
#     312             compression=compression,
#     313             encoding=encoding,
#     314             errors=errors,
#     315             newline=newline,
#     316         )
#     317         for path in paths
#     318     ],
#     319     mode=mode,
#     320     fs=fs,
#     321 )
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\fsspec\core.py:73, in OpenFile.__init__(self, fs, path, mode, compression, encoding, errors, newline)
#      71 self.path = path
#      72 self.mode = mode
# ---> 73 self.compression = get_compression(path, compression)
#      74 self.encoding = encoding
#      75 self.errors = errors
#
# File ~\anaconda3\envs\bert-ode\lib\site-packages\fsspec\core.py:508, in get_compression(urlpath, compression)
#     506     compression = infer_compression(urlpath)
#     507 if compression is not None and compression not in compr:
# --> 508     raise ValueError("Compression type %s not supported" % compression)
#     509 return compression
#
# ValueError: Compression type zstd not supported
